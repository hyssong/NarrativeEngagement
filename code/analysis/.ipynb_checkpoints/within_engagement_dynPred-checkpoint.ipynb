# %% [markdown]
# # Engagement within-dataset prediction
#
# Song, Finn, & Rosenberg (2021) Neural signatures of attentional engagement during narratives and its consequences for event memory, bioRxiv, doi.org/10.1101/2020.08.26.266320
#
# Code by Hayoung Song (hyssong@uchicago.edu)
#
# This code uses leave-one-subject-out cross-validation to build support vector regression models predicting moment-by-moment behavioral data (group-average engagement) from moment-by-moment fMRI measures (dynamic functional connectivity). Feature selection is performed in every round of cross-validation by selecting functional connections (i.e., edges) significantly (*p* < .01) correlated with behavioral in training participants (Shen et al., 2017, *Nat. Protoc.*). Model performance is evaluated with the Fisher's *z*-transformed Pearson's *r* between the predicted and observed behavioral timecourses, averaged across cross-validation folds. Non-parametric significance is evaluated by comparing an actual performance with the permuted null distribution, where null models predict phase-randomized behavioral timecourses (one-tailed test, iteration=1,000).

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import os
from sklearn import svm
from sklearn import metrics
import scipy.io
from scipy import stats
import matplotlib.pyplot as plt
from scipy import stats, linalg
import seaborn as sns
import warnings
from sklearn.exceptions import ConvergenceWarning
def conv_r2z(r):
    with np.errstate(invalid='ignore', divide='ignore'):
        return 0.5 * (np.log(1 + r) - np.log(1 - r))
def conv_z2r(z):
    with np.errstate(invalid='ignore', divide='ignore'):
        return (np.exp(2 * z) - 1) / (np.exp(2 * z) + 1)
# %matplotlib inline
# Out:
# /Users/hayoungsong/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Settings

# %%
## ------------------ select dataset ------------------ ##
dataset = 'paranoia' # 'paranoia'? 'sherlock'?
thres = 0.01 #feature selection: correlation with behavior (one-sample t-test, p < thres)
nR = 122
path = os.path.dirname(os.path.dirname(os.getcwd()))

nsubj = scipy.io.loadmat(path + '/data/hyperparameters.mat')[dataset + '_nsubj'][0][0]
wsize = scipy.io.loadmat(path + '/data/hyperparameters.mat')[dataset + '_wsize'][0]
nT = scipy.io.loadmat(path + '/data/hyperparameters.mat')[dataset + '_nT'][0][0]

print('Within-dataset prediction')
print('  dataset = '+str(dataset))
print('  nsubj   = '+str(nsubj))
print('  nregion = '+str(nR))
print('  thres   = '+str(thres))
print('  wsize   = '+str(wsize))

## ------------------ select wsize option ------------------ ##
wsize = wsize[1]
print('  selected wsize   = '+str(wsize))
# Out:
# Within-dataset prediction
#   dataset = paranoia
#   nsubj   = 22
#   nregion = 122
#   thres   = 0.01
#   wsize   = [32 40 48]
#   selected wsize   = 40

# %% [markdown]
# ## Load behavior data

# %%
engagement = scipy.io.loadmat(path + '/data_processed/' + dataset + '/win'+str(wsize) + '/sliding-engagement.mat')['sliding_engagement'][:,0]
engagement = scipy.stats.zscore(engagement)
plt.plot(engagement)
plt.title(dataset+': sliding-applied group-average engagement')
print(engagement.shape)
# Out:
# (1270,)

# %% [markdown]
# ## Load brain data

# %%
dynFeat = scipy.io.loadmat(path + '/data_processed/' + dataset + '/win'+str(wsize) + '/sliding-dynFeat.mat')['dynFeat']
dynFeat = scipy.stats.zscore(dynFeat,2,nan_policy='omit') # zscore per feature
print(dynFeat.shape)

plt.plot(dynFeat[0,100,:])
plt.plot(dynFeat[10,100,:])
plt.plot(dynFeat[10,400,:])
plt.title('sample FC timecourse')
# Out:
# (22, 7381, 1270)
# Text(0.5, 1.0, 'sample FC timecourse')

# %% [markdown]
# ## Leave-one-subject-out cross-validation
#
# 1. y-predicted: sliding-window applied group-average engagement time course
# 2. x-predictor: sliding-window applied time-varying functional connectivity patterns (*multi-variate*)
# 3. Feature selection: features that are correlated with behavior within the training dataset (Shen et al., 2017, *Nat. Protoc.*)
# 4. Support vector regression (non-linear rbf kernel)
# 5. Leave-one-subject-out cross-validation: Model training in all but one participants, model testing on the held-out participant.
# 5. Prediction accuracy = mean (Pearson's *r* between the predicted and observed group-average engagement, per cross-validation)

# %%
def losocv(fmri, behavior, nsubj, rvals):
    output_acc, output_eval, output_pos_feat, output_neg_feat = [], [], np.zeros((nsubj, nR, nR)), np.zeros((nsubj, nR, nR))
    for test_sub in range(nsubj):

        # separate train-test subject
        test_fmri = fmri[test_sub,:,:]
        train_fmri = np.delete(fmri,test_sub,0)

        # every training participants' data are concatenated
        # fed as independent instances to the model
        train_feature = np.transpose(train_fmri,(1,0,2))
        train_feature = np.reshape(train_feature,(train_feature.shape[0],train_feature.shape[1]*train_feature.shape[2]))
        train_behavior = []
        for sub in range(nsubj-1):
            train_behavior.append(behavior)
        train_behavior = np.asarray(train_behavior)
        train_behavior = np.reshape(train_behavior,(train_behavior.shape[0]*train_behavior.shape[1]))

        # features: correlation with behavior
        train_subj_corrmat = np.delete(rvals,test_sub,0)

        # feature selection
        pos_feat, neg_feat, all_feat, nanval = [], [], [], 0
        idx = -1
        for feat in range(int(nR*(nR-1)/2)):
            idx=idx+1
            if np.any(np.isnan(train_subj_corrmat[:,feat])):
                nanval = nanval+1
                pass
            else:
                [tval,pval] = scipy.stats.ttest_1samp(train_subj_corrmat[:,feat],0)
                if pval < thres:
                    if np.average(train_subj_corrmat[:,feat])>0:
                        all_feat.append(idx)
                        pos_feat.append(idx)
                    elif np.average(train_subj_corrmat[:,feat])<0:
                        all_feat.append(idx)
                        neg_feat.append(idx)
        pos_feat, neg_feat, all_feat = np.asarray(pos_feat), np.asarray(neg_feat), np.asarray(all_feat)

        # summarize feature matrix
        idx = -1
        for i1 in range(nR-1):
            for i2 in range(i1+1,nR):
                idx = idx+1
                if idx in pos_feat:
                    output_pos_feat[test_sub,i1,i2]=1
                    output_pos_feat[test_sub,i2,i1]=1
                if idx in neg_feat:
                    output_neg_feat[test_sub,i1,i2]=1
                    output_neg_feat[test_sub,i2,i1]=1

        train_selected_feat = train_feature[all_feat,:]
        test_selected_feat = test_fmri[all_feat, :]
        test_behavior = behavior

        # if any of the TRs are removed
        rmtr_train = []
        for tm in range(train_selected_feat.shape[1]):
            if np.all(np.isnan(train_selected_feat[:,tm])):
                rmtr_train.append(tm)
        rmtr_train = np.asarray(rmtr_train)
        if len(rmtr_train)>0:
            train_selected_feat = np.delete(train_selected_feat,rmtr_train,1)
            train_behavior = np.delete(train_behavior,rmtr_train,0)

        rmtr_test = []
        for tm in range(test_selected_feat.shape[1]):
            if np.all(np.isnan(test_selected_feat[:, tm])):
                rmtr_test.append(tm)
        rmtr_test = np.asarray(rmtr_test)
        if len(rmtr_test) > 0:
            test_selected_feat = np.delete(test_selected_feat, rmtr_test, 1)
            test_behavior = np.delete(test_behavior,rmtr_test,0)

        # Support vector regression with non-linear kernel
        clf = []
        clf = svm.SVR(kernel='rbf',max_iter=1000, gamma='auto')
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", category=ConvergenceWarning)
            clf.fit(train_selected_feat.T, train_behavior)
        predicted = clf.predict(test_selected_feat.T)
        output_acc.append(predicted)

        # evaluate
        pearsonr = scipy.stats.pearsonr(test_behavior, predicted)
        mse = metrics.mean_squared_error(test_behavior, predicted)
        rsq = metrics.r2_score(test_behavior, predicted)
        output_eval.append([pearsonr[0], mse, rsq])
        print('  subj '+str(test_sub+1)+' / '+str(nsubj)+': #feat '+str(len(all_feat))+', pearson r='+str(np.round(pearsonr[0],3)),', mse='+str(np.round(mse,3))+', rsq='+str(np.round(rsq,3)))
        print('               (train) ft '+str(train_selected_feat.shape[1])+', beh '+str(train_behavior.shape[0])+
              ', (test) ft '+str(test_selected_feat.shape[1])+', beh '+str(test_behavior.shape[0]))

    output_acc, output_eval, output_pos_feat, output_neg_feat = np.asarray(output_acc), np.asarray(output_eval), np.asarray(output_pos_feat), np.asarray(output_neg_feat)
    return output_acc, output_eval, output_pos_feat, output_neg_feat

# %%
# calculate correlation with behavior (engagement) for all FC features
allsubj_corrmat = np.zeros((nsubj,int(nR*(nR-1)/2)))
# for Sherlock, some participants' MNI-aligned images contain zero voxel (node 24 and 82)
for sub in range(nsubj):
    if dataset=='sherlock' and sub == 4:
        for feat in range(int(nR*(nR-1)/2)):
            if np.any(np.isnan(dynFeat[sub,feat,:nT-wsize-51]))==True:
                rval=np.nan
            else:
                [rval,pval] = scipy.stats.pearsonr(dynFeat[sub,feat,:nT-wsize-51], engagement[:nT-wsize-51])
            allsubj_corrmat[sub,feat] = rval
    else:
        for feat in range(int(nR*(nR-1)/2)):
            if np.any(np.isnan(dynFeat[sub,feat,:]))==True:
                rval=np.nan
            else:
                [rval,pval] = scipy.stats.pearsonr(dynFeat[sub,feat,:], engagement)
            allsubj_corrmat[sub,feat] = rval
print(allsubj_corrmat.shape)
# Out:
# (22, 7381)

# %%
[output_acc, output_eval, output_pos_feat, output_neg_feat] = losocv(dynFeat, engagement, nsubj, allsubj_corrmat)
# Out:
#   subj 1 / 22: #feat 293, pearson r=0.586 , mse=0.674, rsq=0.326
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 2 / 22: #feat 315, pearson r=0.198 , mse=0.987, rsq=0.013
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 3 / 22: #feat 311, pearson r=0.448 , mse=0.801, rsq=0.199
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 4 / 22: #feat 297, pearson r=0.492 , mse=0.758, rsq=0.242
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 5 / 22: #feat 306, pearson r=0.351 , mse=0.885, rsq=0.115
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 6 / 22: #feat 290, pearson r=0.352 , mse=0.89, rsq=0.11
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 7 / 22: #feat 292, pearson r=0.409 , mse=0.837, rsq=0.163
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 8 / 22: #feat 300, pearson r=0.184 , mse=1.003, rsq=-0.003
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 9 / 22: #feat 289, pearson r=0.474 , mse=0.777, rsq=0.223
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 10 / 22: #feat 290, pearson r=0.362 , mse=0.903, rsq=0.097
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 11 / 22: #feat 305, pearson r=0.115 , mse=1.061, rsq=-0.061
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 12 / 22: #feat 305, pearson r=0.336 , mse=0.897, rsq=0.103
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 13 / 22: #feat 269, pearson r=0.555 , mse=0.693, rsq=0.307
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 14 / 22: #feat 305, pearson r=0.277 , mse=0.947, rsq=0.053
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 15 / 22: #feat 277, pearson r=0.372 , mse=0.865, rsq=0.135
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 16 / 22: #feat 287, pearson r=0.214 , mse=0.974, rsq=0.026
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 17 / 22: #feat 284, pearson r=0.55 , mse=0.707, rsq=0.293
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 18 / 22: #feat 316, pearson r=0.149 , mse=1.047, rsq=-0.047
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 19 / 22: #feat 300, pearson r=0.451 , mse=0.811, rsq=0.189
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 20 / 22: #feat 286, pearson r=0.556 , mse=0.718, rsq=0.282
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 21 / 22: #feat 285, pearson r=0.342 , mse=0.899, rsq=0.101
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 22 / 22: #feat 281, pearson r=0.409 , mse=0.837, rsq=0.163
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270

# %% [markdown]
# ## Save output

# %%
savepath=path+'/result/dynPred/'+str(dataset)+'/win'+str(wsize)
result = {'acc':output_acc, 'eval':output_eval, 'pos_feat':output_pos_feat, 'neg_feat':output_neg_feat}
if os.path.exists(savepath)==0:
    os.makedirs(savepath)
scipy.io.savemat(savepath+'/within_engagement.mat',result)

# %% [markdown]
# ## Check cross-validation prediction accuracy

# %%
fig, axs = plt.subplots(1,3)
axs[0].hist(output_eval[:,0])
axs[0].set_title('Pearson correlation')
axs[1].hist(output_eval[:,1])
axs[1].set_title('MSE')
axs[2].hist(output_eval[:,2])
axs[2].set_title('r-squared')

print('Prediction result (mean of cross-validations): '+dataset)
print(' pearson r = '+str(np.round(conv_z2r(np.mean(conv_r2z(output_eval[:,0]))),3)))
print(' MSE       = '+str(np.round(np.mean(output_eval[:,1]),3)))
print(' r-squared = '+str(np.round(np.mean(output_eval[:,2]),3)))
# Out:
# Prediction result (mean of cross-validations): paranoia
#  pearson r = 0.38
#  MSE       = 0.862
#  r-squared = 0.138

# %% [markdown]
# ## Non-parametric permutation tests
#
# Type 1 comparison: specificity of behavioral outcome
# - Phase-randomize group-average engagement timecourse
# - Using the same multivariate funcitonal connectivity patterns, predict phase-randomized engagement.
#
# Type 2 comparison: specificity of neural features
# - Random selection of size-matched functional connections
# - Using different neural features, predict an actual group-average engagement.
#
# Song et al. (2021) used iteration = 1,000, with one-tailed non-parametric test, p = (1 + number of null r values ≥ empirical r) / (1 + number of permutations)
# Here, we are going to conduct Type 1 permutation test. Surrogate behavioral data is pre-saved.

# %%
niter = 2
# permutation takes huge amount of time, so let's try with small number

engagement_surr = scipy.io.loadmat(path+'/data_processed/'+dataset+'/win'+str(wsize)+'/sliding-engagement-surr.mat')['sliding_surr_engagement'][:,:niter]
print('phase randomized engagement rating: shape '+str(engagement_surr.shape))

# plot sample phase-randomized engagement time course
plt.plot(engagement_surr[:,:3])
plt.plot(engagement,color='black')
plt.title('phase randomized engagement: sample ='+str(niter))
# Out:
# phase randomized engagement rating: shape (1270, 2)
# Text(0.5, 1.0, 'phase randomized engagement: sample =2')

# %%
if not os.path.exists(savepath+'/within_engagement_null'):
    os.makedirs(savepath+'/within_engagement_null')

print('Null prediction results: iter = '+str(niter))
surr_pearsonr, surr_mse, surr_rsq = [], [], []
for iter in range(niter):
    print('null '+str(iter+1)+' / '+str(niter))
    # calculate correlation with behavior (engagement) for all FC features
    surr_corrmat = np.zeros((nsubj,int(nR*(nR-1)/2)))
    for sub in range(nsubj):
        if dataset=='sherlock' and sub==4:
            for feat in range(int(nR*(nR-1)/2)):
                if np.any(np.isnan(dynFeat[sub,feat,:nT-wsize-51])) == True:
                    rval=np.nan
                else:
                    [rval, pval] = scipy.stats.pearsonr(dynFeat[sub,feat,:nT-wsize-51],engagement_surr[:nT-wsize-51,iter])
                surr_corrmat[sub,feat] = rval
        else:
            for feat in range(int(nR*(nR-1)/2)):
                if np.any(np.isnan(dynFeat[sub,feat,:]))==True:
                    rval=np.nan
                else:
                    [rval,pval] = scipy.stats.pearsonr(dynFeat[sub,feat,:], engagement_surr[:,iter])
                surr_corrmat[sub,feat] = rval
    
    [surr_acc, surr_eval, surr_pos_feat, surr_neg_feat] = losocv(dynFeat, engagement_surr[:,iter], nsubj, surr_corrmat)
    surr_pearsonr.append(surr_eval[:,0])
    surr_mse.append(surr_eval[:,1])
    surr_rsq.append(surr_eval[:,2])
    print('null '+str(iter+1)+' / '+str(niter)+
          ' : pearson r = '+str(np.round(conv_z2r(np.mean(conv_r2z(surr_eval[:,0]))),3))+
          ', mse = '+str(np.round(np.average(surr_eval[:,1]),3))+
          ', rsq = '+str(np.round(np.average(surr_eval[:,2]),3)))
    
    result = {'acc':surr_acc, 'eval':surr_eval, 'pos_feat':surr_pos_feat, 'neg_feat':surr_neg_feat}
    scipy.io.savemat(savepath+'/within_engagement_null/null'+str(iter+1)+'.mat',result)

surr_pearsonr, surr_mse, surr_rsq = np.asarray(surr_pearsonr), np.asarray(surr_mse), np.asarray(surr_rsq)
# Out:
# Null prediction results: iter = 2
# null 1 / 2
#   subj 1 / 22: #feat 222, pearson r=0.415 , mse=0.833, rsq=0.167
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 2 / 22: #feat 235, pearson r=0.282 , mse=0.942, rsq=0.057
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 3 / 22: #feat 243, pearson r=0.117 , mse=1.092, rsq=-0.093
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 4 / 22: #feat 221, pearson r=0.203 , mse=1.056, rsq=-0.057
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 5 / 22: #feat 225, pearson r=0.558 , mse=0.704, rsq=0.296
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 6 / 22: #feat 226, pearson r=0.153 , mse=1.043, rsq=-0.044
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 7 / 22: #feat 231, pearson r=0.03 , mse=1.133, rsq=-0.133
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 8 / 22: #feat 221, pearson r=0.278 , mse=0.938, rsq=0.061
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 9 / 22: #feat 216, pearson r=0.361 , mse=0.892, rsq=0.107
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 10 / 22: #feat 220, pearson r=0.29 , mse=0.948, rsq=0.051
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 11 / 22: #feat 225, pearson r=0.228 , mse=0.969, rsq=0.03
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 12 / 22: #feat 212, pearson r=0.266 , mse=0.97, rsq=0.03
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 13 / 22: #feat 211, pearson r=0.108 , mse=1.069, rsq=-0.07
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 14 / 22: #feat 238, pearson r=0.185 , mse=1.086, rsq=-0.087
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 15 / 22: #feat 220, pearson r=0.461 , mse=0.793, rsq=0.206
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 16 / 22: #feat 205, pearson r=0.497 , mse=0.754, rsq=0.245
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 17 / 22: #feat 204, pearson r=0.558 , mse=0.694, rsq=0.305
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 18 / 22: #feat 231, pearson r=0.317 , mse=0.902, rsq=0.097
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 19 / 22: #feat 213, pearson r=0.498 , mse=0.763, rsq=0.237
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 20 / 22: #feat 221, pearson r=0.161 , mse=1.057, rsq=-0.058
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 21 / 22: #feat 253, pearson r=0.127 , mse=1.091, rsq=-0.092
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 22 / 22: #feat 199, pearson r=0.633 , mse=0.613, rsq=0.386
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
# null 1 / 2 : pearson r = 0.317, mse = 0.925, rsq = 0.075
# null 2 / 2
#   subj 1 / 22: #feat 204, pearson r=0.193 , mse=1.003, rsq=-0.004
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 2 / 22: #feat 201, pearson r=0.158 , mse=1.058, rsq=-0.059
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 3 / 22: #feat 191, pearson r=0.008 , mse=1.202, rsq=-0.203
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 4 / 22: #feat 220, pearson r=0.181 , mse=1.06, rsq=-0.061
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 5 / 22: #feat 186, pearson r=0.055 , mse=1.14, rsq=-0.141
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 6 / 22: #feat 199, pearson r=0.013 , mse=1.136, rsq=-0.137
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 7 / 22: #feat 174, pearson r=0.322 , mse=0.917, rsq=0.083
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 8 / 22: #feat 174, pearson r=0.469 , mse=0.783, rsq=0.216
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 9 / 22: #feat 205, pearson r=0.006 , mse=1.122, rsq=-0.123
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 10 / 22: #feat 214, pearson r=-0.218 , mse=1.382, rsq=-0.383
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 11 / 22: #feat 190, pearson r=0.269 , mse=0.957, rsq=0.042
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 12 / 22: #feat 197, pearson r=0.222 , mse=1.002, rsq=-0.003
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 13 / 22: #feat 186, pearson r=0.258 , mse=0.976, rsq=0.024
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 14 / 22: #feat 189, pearson r=-0.109 , mse=1.272, rsq=-0.273
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 15 / 22: #feat 159, pearson r=0.317 , mse=0.908, rsq=0.091
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 16 / 22: #feat 182, pearson r=0.14 , mse=1.088, rsq=-0.089
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 17 / 22: #feat 182, pearson r=-0.141 , mse=1.381, rsq=-0.382
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 18 / 22: #feat 194, pearson r=0.201 , mse=0.978, rsq=0.021
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 19 / 22: #feat 185, pearson r=0.264 , mse=1.019, rsq=-0.02
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 20 / 22: #feat 179, pearson r=0.363 , mse=0.871, rsq=0.128
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 21 / 22: #feat 204, pearson r=0.083 , mse=1.075, rsq=-0.076
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
#   subj 22 / 22: #feat 198, pearson r=0.038 , mse=1.125, rsq=-0.126
#                (train) ft 26670, beh 26670, (test) ft 1270, beh 1270
# null 2 / 2 : pearson r = 0.144, mse = 1.066, rsq = -0.067

# %% [markdown]
# ## Compare an actual prediction accuracy with null distribution

# %%
def onetail_p(real, null):
    p = (1 + np.sum(null>=real)) / (1+len(null))
    print(str(np.sum(null>=real))+' among '+str(len(null))+' null has higher r value than actual prediction')
    return p

# %%
p = onetail_p(conv_z2r(np.mean(conv_r2z(output_eval[:,0]))), conv_z2r(np.average(conv_r2z(surr_pearsonr),1)))
print('p = '+str(np.round(p,3)))
# Out:
# 0 among 2 null has higher r value than actual prediction
# p = 0.333

# %%
plt.hist(conv_z2r(np.average(conv_r2z(surr_pearsonr),1)))
plt.vlines(conv_z2r(np.mean(conv_r2z(output_eval[:,0]))),0,2)
